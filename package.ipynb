# %%
import selenium 
from selenium import webdriver as wb
web=wb.Chrome('chromedriver.exe')
#web.get('https://www.practo.com/tests?city=delhi')

l2=[]
alldetails=[]
cities=['Delhi','Mumbai','Noida','navi-mumbai','Faridabad','Ahmedabad','Jodhpur','Ludhiana','Visakhapatnam','Nagpur','Karnal','Surat','Raigarh','Gurgaon','Thane','Hyderabad','Chennai','Bhubaneswar','Indore','Lucknow','Patna','Ernakulam','Aurangabad','Bhopal','Medak','Mohali','Salem','Rangareddy','Bangalore','Pune','Kolkata','Coimbatore','Chandigarh','Ghaziabad','Jaipur','Vadodara','Panchkula','Raipur','Madurai','Vijayawada']
checkup=['diabetes-checkup','cancer-screening-health-checkup','skin-care-checkups','kidney-urine-checkups','stomach-digestion-checkups','sexual-wellness-checkups','bone-joints-checkups','fever-checkup']
try:
    for b in checkup:
    
        for a in cities:
            a = a.lower()
    
            web.get('https://www.practo.com/health-checkup-packages/'+b+'?'+'city='+a)
        
            li1=web.find_element_by_id('packages')
            li2=li1.find_elements_by_css_selector('a')
            for i in li2:
    
                l2.append(i.get_attribute('href'))
        
    l3=[]
    for i in range(len(l2)):
        if(i%2==0):
            l3.append(l2[i])

        
    
    for j in l3: 
        web.get(j)
    
        name=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[5]/div/div[2]/div[1]').text
        test=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[4]/div/div[2]/div/div[2]').text
        price=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[5]/div/div[4]/span[2]').text
        age=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[4]/div/div[2]/div/div[1]').text
        prep=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[4]/div/div[6]').text
        book=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[4]/div/div[8]').text
        
        
        
        #include_test=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[4]/div/div[11]/div').text
        temp={'test':test,
              'name':name,
               'ideal_age':age,
               'price':price,
              'prepation':prep,
              'who should book':book,
                  'city':j
                  
             }
        alldetails.append(temp)
           
    
except:
    print('thanks')
# Out:
# thanks

# %%
import selenium 
from selenium import webdriver as wb
web=wb.Chrome('chromedriver.exe')
alldetails=[]
try:
    
    for j in l3: 
        web.get(j)
    
        name=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[5]/div/div[2]/div[1]').text
        
        test=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[4]/div/div[2]/div/div[2]').text
        
        price=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[5]/div/div[4]/span[2]').text
        
        age=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[4]/div/div[2]/div/div[1]').text
        
        #prep=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[4]/div/div[6]').text
        #continue
        #book=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[4]/div/div[8]').text
        #continue
        
        
        #include_test=web.find_element_by_xpath('//*[@id="root-app"]/div/div/div[2]/div/div[1]/div[4]/div/div[11]/div').text
        temp={'test':test,
              'name':name,
               'ideal_age':age,
               'price':price,
              #'prepation':prep,
              #'who should book':book,
                  'city':j
                  
             }
        alldetails.append(temp)
except:
    print('thanks')
# Out:
# thanks

# %%
import pandas as pd
df=pd.DataFrame(alldetails)

# %%
alldetails
# Out:
# [{'test': 'Includes 89 tests',
#   'name': "Advanced Diabetic Patient's Health Checkup\nIncludes 89 tests",
#   'ideal_age': 'Ideal for individuals aged 35-85 years',
#   'price': '₹3599',
#   'city': 'https://www.practo.com/health-checkup-packages/advanced-diabetic-patients-health-checkup/p?tag_id=28&city=delhi'},
#  {'test': 'Includes 70 tests',
#   'name': 'Advanced Diabetic Screening Checkup\nIncludes 70 tests',
#   'ideal_age': 'Ideal for individuals aged 35-85 years',
#   'price': '₹2199',
#   'city': 'https://www.practo.com/health-checkup-packages/advanced-diabetic-screening-checkup/p?tag_id=28&city=delhi'},
#  {'test': 'Includes 66 tests',
#   'name': 'Basic Diabetic Screening Checkup\nIncludes 66 tests',
#   'ideal_age': 'Ideal for individuals aged 20-40 years',
#   'price': '₹1599',
#   'city': 'https://www.practo.com/health-checkup-packages/basic-diabetic-screening-checkup/p?tag_id=28&city=delhi'},
#  {'test': 'Includes 77 tests',
# ...

# %%
l3
# Out:
# ['https://www.practo.com/health-checkup-packages/advanced-diabetic-patients-health-checkup/p?tag_id=28&city=delhi',
#  'https://www.practo.com/health-checkup-packages/advanced-diabetic-screening-checkup/p?tag_id=28&city=delhi',
#  'https://www.practo.com/health-checkup-packages/basic-diabetic-screening-checkup/p?tag_id=28&city=delhi',
#  'https://www.practo.com/health-checkup-packages/diabetic-patients-health-checkup/p?tag_id=28&city=delhi',
#  'https://www.practo.com/health-checkup-packages/advanced-diabetic-patients-health-checkup/p?tag_id=28&city=mumbai',
#  'https://www.practo.com/health-checkup-packages/advanced-diabetic-screening-checkup/p?tag_id=28&city=mumbai',
#  'https://www.practo.com/health-checkup-packages/basic-diabetic-screening-checkup/p?tag_id=28&city=mumbai',
#  'https://www.practo.com/health-checkup-packages/diabetic-patients-health-checkup/p?tag_id=28&city=mumbai',
# ...

# %%
len(l3)
# Out:
# 659
